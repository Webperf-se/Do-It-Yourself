# %% [markdown]
# # Kodexempel för api.webperf.se
# Denna kodresurs använder sig av Jupyter notebooks, vilket du kan köra direkt i webbläsaren hos [Google Colab](https://colab.research.google.com/) ifall du har ett Google-konto. Om du kan installera saker på din dator är också [Anaconda + Jupyter](https://www.anaconda.com/products/distribution) ett bra val.
#
# Nedan visas några exempel på hur du kan jobba med Webperfs API, samt koppla ihop det med information från andra datakällor du når över internet.

# %% [markdown]
# ## 1. Hämta listan med kommuner och regioner
#
# Förlitar sig på:
# * [requests](https://requests.readthedocs.io/en/latest/)
# * [json](https://docs.python.org/3/library/json.html)

# %%
import requests
import json

r = requests.get('https://api.webperf.se/public-sector/') # gör själva frågan till API:t
webbplatser = dict() # i denna ordlista kommer vi spara ner alla webbplatsernas data för att jobba med

if r.status_code != 200:
    # om statuskoden inte är 200 har API:t svarat att något gått på tok
    print("Ett fel inträffade på serversidan!")
else:
    api_svar = json.loads(r.text) # läser in API-svaret till 
    
    print(f"API-version: {api_svar['api_version']} \nAntal webbplatser: {api_svar['result_count']} \nTidpunkt: {api_svar['timestamp']}")
    
    for webbplats in api_svar['data']:
        webbplatser[webbplats['title']] = [webbplats['url'], webbplats['uri'], webbplats['category'], webbplats['sameAs']]
    
    print('\nGREAT SUCCESS! Webbplatserna inlästa i en lista! Fortsätt med nedan kodcell.')
# Out:
# API-version: 0.1
# Antal webbplatser: 310
# Tidpunkt: 2022-08-14 19:40:10.400881
#
# GREAT SUCCESS! Webbplatserna inlästa i en lista! Fortsätt med nedan kodcell.

# %% [markdown]
# ## 1.1 Jobba med listan
# Kör först kodcellen för "1", sedan kan du använda nedan kod

# %%
print(f'Antal webbplatser i listan: {len(webbplatser)} st')

# skriv ut namnen på respektive organisation och deras webbadress
for webbplats in webbplatser:
    print(webbplats, webbplatser[webbplats][0]) # hämtar webbplatsens adress, det vill säga plats 0 i arrayen med data
# Out:
# Antal webbplatser i listan: 310 st
# Arvidsjaurs kommun https://www.arvidsjaur.se
# Bergs kommun https://www.berg.se
# Bollebygds kommun https://bollebygd.se
# Botkyrka kommun https://www.botkyrka.se
# Båstads kommun https://www.bastad.se
# Degerfors kommun https://www.degerfors.se
# Dorotea kommun https://www.dorotea.se
# Eskilstuna kommun https://www.eskilstuna.se
# Falkenbergs kommun https://kommun.falkenberg.se
# Falköpings kommun https://www.falkoping.se
# Falu kommun https://www.falun.se
# Forshaga kommun https://www.forshaga.se
# Gnesta kommun https://www.gnesta.se
# Grums kommun https://www.grums.se
# Gullspångs kommun https://gullspang.se/Gullspangs-kommun.html
# Gävle kommun https://www.gavle.se
# Götene kommun https://www.gotene.se
# Halmstads kommun https://www.halmstad.se
# Haparanda kommun https://www.haparanda.se
# Heby kommun https://heby.se
# Helsingborgs kommun https://helsingborg.se
# Huddinge kommun https://www.huddinge.se
# Hultsfreds kommun https://www.hultsfred.se
# Hylte kommun https://www.hylte.se
# Håbo kommun https://www.habo.se
# Hällefors kommun https://www.hellefors.se
# Härnösands kommun https://harnosand.se
# Kalix kommun https://www.kalix.se
# Karlshamns kommun https://www.karlshamn.se
# Karlskoga kommun https://karlskoga.se
# Karlskrona kommun https://www.karlskrona.se
# Karlstads kommun https://karlstad.se
# Kinda kommun https://www.kinda.se
# Kramfors kommun https://www.kramfors.se
# Krokoms kommun https://www.krokom.se
# Region Kronoberg https://www.regionkronoberg.se
# Lekebergs kommun https://lekeberg.se
# Lerums kommun https://lerum.se
# Lidingö kommun https://www.lidingo.se
# Lidköpings kommun https://lidkoping.se
# Lindesbergs kommun https://www.lindesberg.se
# Linköpings kommun https://www.linkoping.se
# Ljungby kommun https://www.ljungby.se
# Luleå kommun https://www.lulea.se
# Lunds kommun https://lund.se
# Mariestads kommun https://mariestad.se/Mariestads-kommun.html
# Mölndals kommun https://www.molndal.se
# Nacka kommun https://www.nacka.se
# Norrköpings kommun https://norrkoping.se
# Olofströms kommun https://olofstrom.se
# Orusts kommun https://www.orust.se
# Oxelösunds kommun https://www.oxelosund.se
# Piteå kommun https://www.pitea.se
# Ragunda kommun https://www.ragunda.se
# Region Gotland https://www.gotland.se
# Region Skåne https://www.skane.se
# Sala kommun https://www.sala.se
# Salems kommun https://www.salem.se
# Sandvikens kommun https://sandviken.se
# Simrishamns kommun https://www.simrishamn.se
# Sjöbo kommun https://www.sjobo.se
# Skellefteå kommun https://skelleftea.se/invanare/
# Skinnskattebergs kommun https://www.skinnskatteberg.se
# Skövde kommun https://www.skovde.se
# Sollentuna kommun https://www.sollentuna.se
# Stockholms kommun https://start.stockholm
# Strängnäs kommun https://www.strangnas.se
# Strömsunds kommun https://www.stromsund.se
# Sundbybergs kommun https://www.sundbyberg.se
# Sundsvalls kommun https://sundsvall.se
# Sunne kommun https://sunne.se
# Söderhamns kommun https://www.soderhamn.se
# Söderköpings kommun https://www.soderkoping.se
# Södertälje kommun https://www.sodertalje.se
# Sölvesborgs kommun https://www.solvesborg.se
# Tanums kommun https://www.tanum.se
# Tidaholms kommun https://www.tidaholm.se
# Tierps kommun https://www.tierp.se
# Timrå kommun https://www.timra.se
# Tjörns kommun https://www.tjorn.se
# Tomelilla kommun https://www.tomelilla.se
# Torsby kommun https://www.torsby.se
# Tranås kommun https://www.tranas.se
# Trollhättans kommun https://www.trollhattan.se
# Töreboda kommun https://toreboda.se/Toreboda-kommun.html
# Uddevalla kommun https://www.uddevalla.se
# Umeå kommun https://www.umea.se
# Upplands Väsby kommun https://www.upplandsvasby.se
# Upplands-bro kommun https://www.upplands-bro.se
# Uppsala kommun https://www.uppsala.se
# Vara kommun https://vara.se
# Varbergs kommun https://varberg.se
# Vetlanda kommun https://vetlanda.se
# Vimmerby kommun https://www.vimmerby.se
# Vindelns kommun https://www.vindeln.se
# Vårgårda kommun https://www.vargarda.se
# Värmdö kommun https://www.varmdo.se
# Västerviks kommun https://www.vastervik.se
# Västerås kommun https://www.vasteras.se
# Västra Götalandsregionen https://www.vgregion.se
# Ystads kommun https://www.ystad.se
# Ånge kommun https://www.ange.se
# Åsele kommun https://www.asele.se
# Älvkarleby kommun https://www.alvkarleby.se
# Ängelholms kommun https://www.engelholm.se
# Örebro kommun https://www.orebro.se
# Östersunds kommun https://www.ostersund.se
# Ale kommun https://www.ale.se
# Alingsås kommun https://www.alingsas.se
# Alvesta kommun https://www.alvesta.se
# Aneby kommun https://www.aneby.se
# Arboga kommun https://www.arboga.se
# Arjeplogs kommun https://www.arjeplog.se
# Arvika kommun https://www.arvika.se
# Askersunds kommun https://www.askersund.se
# Avesta kommun https://www.avesta.se
# Bengtsfors kommun https://www.bengtsfors.se
# Bjurholms kommun https://www.bjurholm.se
# Bjuvs kommun https://www.bjuv.se
# Bodens kommun https://www.boden.se
# Bollnäs kommun https://bollnas.se
# Borgholms kommun https://www.borgholm.se
# Borlänge kommun https://www.borlange.se
# Borås kommun https://www.boras.se
# Boxholms kommun https://www.boxholm.se
# Bromölla kommun https://www.bromolla.se
# Bräcke kommun https://www.bracke.se
# Burlövs kommun https://www.burlov.se
# Dals-eds kommun https://www.dalsed.se
# Danderyds kommun https://www.danderyd.se
# Eda kommun https://www.eda.se
# Ekerö kommun https://www.ekero.se
# Eksjö kommun https://www.eksjo.se
# Emmaboda kommun https://www.emmaboda.se
# Enköpings kommun https://enkoping.se
# Eslövs kommun https://eslov.se
# Essunga kommun https://www.essunga.se
# Fagersta kommun https://www.fagersta.se
# Filipstads kommun https://www.filipstad.se
# Finspångs kommun https://www.finspang.se
# Flens kommun https://flen.se
# Färgelanda kommun https://www.fargelanda.se
# Gagnefs kommun https://gagnef.se
# Gislaveds kommun https://www.gislaved.se
# Gnosjö kommun https://www.gnosjo.se
# Grästorps kommun https://www.grastorp.se
# Gällivare kommun http://www.gellivare.se
# Göteborgs kommun https://goteborg.se
# Habo kommun https://www.habokommun.se
# Hagfors kommun https://www.hagfors.se
# Hallsbergs kommun https://www.hallsberg.se
# Hallstahammars kommun https://www.hallstahammar.se
# Hammarö kommun https://www.hammaro.se
# Haninge kommun https://www.haninge.se
# Hedemora kommun https://www.hedemora.se
# Herrljunga kommun https://www.herrljunga.se
# Hjo kommun https://hjo.se
# Hofors kommun https://www.hofors.se
# Hudiksvalls kommun https://www.hudiksvall.se
# Härjedalens kommun https://www.herjedalen.se
# Härryda kommun https://www.harryda.se
# Hässleholms kommun https://www.hassleholm.se
# Höganäs kommun https://www.hoganas.se/Invanare/
# Högsby kommun https://www.hogsby.se
# Hörby kommun https://www.horby.se
# Höörs kommun https://www.hoor.se
# Jokkmokks kommun https://www.jokkmokk.se
# Region Jämtland Härjedalen https://www.regionjh.se
# Järfälla kommun https://www.jarfalla.se
# Jönköpings kommun https://www.jonkoping.se
# Kalmar kommun https://www.kalmar.se
# Karlsborgs kommun https://www.karlsborg.se
# Katrineholms kommun https://www.katrineholm.se
# Kils kommun https://www.kil.se
# Kiruna kommun https://kiruna.se
# Klippans kommun https://www.klippan.se
# Knivsta kommun https://knivsta.se
# Kristianstads kommun https://www.kristianstad.se
# Kristinehamns kommun https://www.kristinehamn.se
# Kumla kommun https://www.kumla.se
# Kungsbacka kommun https://kungsbacka.se
# Kungsörs kommun https://kungsor.se
# Kungälvs kommun https://www.kungalv.se
# Kävlinge kommun https://www.kavlinge.se
# Köpings kommun https://koping.se
# Laholms kommun https://www.laholm.se
# Landskrona kommun https://www.landskrona.se
# Region Blekinge https://regionblekinge.se
# Region Dalarna https://www.regiondalarna.se
# Region Gävleborg https://www.regiongavleborg.se
# Region Jönköpings Län https://www.rjl.se
# Region Kalmar län https://www.regionkalmar.se
# Region Uppsala https://regionuppsala.se
# Region Värmland https://www.regionvarmland.se
# Region Östergötland https://www.regionostergotland.se
# Region Sörmland https://www.regionsormland.se
# Region Västernorrland https://www.rvn.se
# Region Västmanland https://regionvastmanland.se
# Laxå kommun https://www.laxa.se
# Leksands kommun https://www.leksand.se
# Lessebo kommun https://www.lessebo.se
# Lilla Edets kommun https://www.lillaedet.se
# Ljusdals kommun https://www.ljusdal.se
# Ljusnarsbergs kommun https://www.ljusnarsberg.se
# Lomma kommun https://lomma.se
# Ludvika kommun https://www.ludvika.se
# Lycksele kommun https://www.lycksele.se
# Lysekils kommun https://www.lysekil.se
# Malmö kommun https://malmo.se
# Malung-Sälens kommun https://malung-salen.se
# Malå kommun https://www.mala.se
# Markaryds kommun https://www.markaryd.se
# Marks kommun https://www.mark.se
# Melleruds kommun https://www.mellerud.se
# Mjölby kommun https://www.mjolby.se
# Mora kommun https://www.morakommun.se
# Motala kommun https://www.motala.se/kommun/
# Mullsjö kommun https://www.mullsjo.se
# Munkedals kommun https://www.munkedal.se
# Munkfors kommun https://www.munkfors.se
# Mönsterås kommun https://www.monsteras.se
# Mörbylånga kommun https://www.morbylanga.se
# Nora kommun https://www.nora.se
# Norbergs kommun https://www.norberg.se
# Nordanstigs kommun https://nordanstig.se
# Nordmalings kommun https://www.nordmaling.se
# Region Norrbotten https://www.norrbotten.se
# Norrtälje kommun https://www.norrtalje.se
# Norsjö kommun https://www.norsjo.se
# Nybro kommun https://nybro.se
# Nykvarns kommun https://www.nykvarn.se
# Nyköpings kommun https://nykoping.se
# Nynäshamns kommun https://nynashamn.se
# Nässjö kommun https://nassjo.se
# Ockelbo kommun https://www.ockelbo.se
# Orsa kommun https://www.orsa.se
# Osby kommun https://www.osby.se
# Oskarshamns kommun https://www.oskarshamn.se
# Ovanåkers kommun https://www.ovanaker.se
# Pajala kommun https://www.pajala.se
# Partille kommun https://www.partille.se
# Perstorps kommun https://www.perstorp.se
# Region Halland https://www.regionhalland.se
# Robertsfors kommun https://www.robertsfors.se
# Ronneby kommun https://www.ronneby.se
# Rättviks kommun https://www.rattvik.se
# Sigtuna kommun https://www.sigtuna.se
# Skara kommun https://www.skara.se
# Skurups kommun https://www.skurup.se
# Smedjebackens kommun https://www.smedjebacken.se
# Sollefteå kommun https://www.solleftea.se
# Solna kommun https://www.solna.se
# Sorsele kommun https://portal.sorsele.se
# Sotenäs kommun https://www.sotenas.se
# Staffanstorps kommun https://staffanstorp.se
# Stenungsunds kommun https://www.stenungsund.se
# Region Stockholm https://www.regionstockholm.se
# Storfors kommun https://www.storfors.se
# Storumans kommun https://www.storuman.se
# Strömstads kommun https://www.stromstad.se
# Surahammars kommun https://www.surahammar.se
# Svalövs kommun https://www.svalov.se
# Svedala kommun https://www.svedala.se
# Svenljunga kommun https://www.svenljunga.se
# Säffle kommun https://saffle.se
# Säters kommun https://www.sater.se
# Sävsjö kommun https://www.savsjo.se
# Tibro kommun https://www.tibro.se
# Tingsryds kommun https://tingsryd.se
# Torsås kommun https://www.torsas.se
# Tranemo kommun https://www.tranemo.se
# Trelleborgs kommun https://www.trelleborg.se
# Trosa kommun https://www.trosa.se
# Tyresö kommun https://www.tyreso.se
# Täby kommun https://www.taby.se
# Ulricehamns kommun https://www.ulricehamn.se
# Uppvidinge kommun https://www.uppvidinge.se
# Vadstena kommun https://www.vadstena.se
# Vaggeryds kommun https://www.vaggeryd.se
# Valdemarsviks kommun https://www.valdemarsvik.se
# Vallentuna kommun https://www.vallentuna.se
# Vansbro kommun https://www.vansbro.se
# Vaxholms kommun https://www.vaxholm.se
# Vellinge kommun https://www.vellinge.se
# Vilhelmina kommun https://www.vilhelmina.se
# Vingåkers kommun https://www.vingaker.se
# Vänersborgs kommun https://www.vanersborg.se
# Vännäs kommun https://www.vannas.se
# Värnamo kommun https://www.varnamo.se
# Region Västerbotten https://www.regionvasterbotten.se
# Växjö kommun https://www.vaxjo.se
# Ydre kommun https://www.ydre.se
# Åmåls kommun https://www.amal.se
# Åre kommun https://are.se
# Årjängs kommun https://www.arjang.se
# Åstorps kommun https://astorp.se
# Åtvidabergs kommun https://www.atvidaberg.se
# Älmhults kommun https://www.almhult.se
# Älvdalens kommun https://www.alvdalen.se
# Älvsbyns kommun https://www.alvsbyn.se
# Öckerö kommun https://www.ockero.se
# Ödeshögs kommun https://www.odeshog.se
# Region Örebro län https://www.regionorebrolan.se
# Örkelljunga kommun https://www.orkelljunga.se
# Örnsköldsviks kommun https://www.ornskoldsvik.se
# Österåkers kommun https://www.osteraker.se
# Östhammars kommun https://www.osthammar.se
# Östra Göinge kommun https://www.ostragoinge.se
# Överkalix kommun https://www.overkalix.se
# Övertorneå kommun https://www.overtornea.se

# %% [markdown]
# ## 1.2 Hämta alla webbplatsernas sidtitlar
# Nu använder vi listan med adresser och ansluter till var och en för att hämta ut sidans sidtitel.
#
# Förlitar sig på:
# * [regex](https://www.w3schools.com/python/python_regex.asp)
# * [requests](https://requests.readthedocs.io/en/latest/)

# %%
import re # det här är regex - Regular Expressions / reguljära uttryck
import requests

for webbplats in webbplatser:
    url_att_hamta = webbplatser[webbplats][0]
    
    try:
        r = requests.get(url_att_hamta)
        x = re.search("<title>(.*?)</title>", r.text)
        sidtitel = x[x.lastindex]
        print(f'{webbplats} har sidtitel: {sidtitel}')
        
        webbplatser[webbplats].append(len(sidtitel)) # vi lägger till längden på sidtiteln inför 1.3
        webbplatser[webbplats].append(sidtitel)
    except Exception as e:
        print(f'ERROR! {webbplats} vill inte. Felmeddelande: {e}')
# Out:
# Arvidsjaurs kommun har sidtitel: Arvidsjaur.se
# Bergs kommun har sidtitel: Bergs kommun - Bergs kommun
# Bollebygds kommun har sidtitel: Bollebygds kommun - Bollebygds kommun
# Botkyrka kommun har sidtitel: Botkyrka kommun - Välkommen till Botkyrka kommuns webbplats
# ERROR! Båstads kommun vill inte. Felmeddelande: HTTPSConnectionPool(host='www.bastad.se', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
# Degerfors kommun har sidtitel: Degerfors kommun - Degerfors kommun
# Dorotea kommun har sidtitel: Dorotea kommuns hemsida
# Eskilstuna kommun har sidtitel: Eskilstuna kommun
# Falkenbergs kommun har sidtitel: Falkenbergs kommun
# Falköpings kommun har sidtitel: Falköpings kommun
# Falu kommun har sidtitel: Startsida - Falu kommun
# Forshaga kommun har sidtitel: Forshaga - Forshaga
# Gnesta kommun har sidtitel: Gnesta kommun - Björnlunda, Stjärnhov, Laxne och Gnesta
# Grums kommun har sidtitel: Grums kommun - Grums kommun
# Gullspångs kommun har sidtitel: Gullspångs kommun
# Gävle kommun har sidtitel: Gävle kommun &#8211; Kommunens service
# Götene kommun har sidtitel: Götene kommun - Götene kommun
# Halmstads kommun har sidtitel: Startsida - Halmstads kommun
# Haparanda kommun har sidtitel: Haparanda stad
# Heby kommun har sidtitel: Heby kommun
# Helsingborgs kommun har sidtitel: Helsingborg.se | Helsingborgs stad
# Huddinge kommun har sidtitel: Huddinge kommun
# Hultsfreds kommun har sidtitel: Hultsfreds kommun | Välkommen till Hultsfreds kommuns webbplats
# Hylte kommun har sidtitel: Hylte kommun - Hylte kommun
# Håbo kommun har sidtitel: Håbo - Håbo
# Hällefors kommun har sidtitel: Hällefors kommun - Hällefors kommun
# Härnösands kommun har sidtitel: Harnosand.se - Harnosand.se
# Kalix kommun har sidtitel: Startsidan f&#246;r kalix.se
# Karlshamns kommun har sidtitel: Startsida - Karlshamns kommun
# ERROR! Karlskoga kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Karlskrona kommun har sidtitel: Startsida - Karlskrona.se
# ERROR! Karlstads kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Kinda kommun har sidtitel: A different Kinda life - Kinda.se
# ERROR! Kramfors kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Krokoms kommun har sidtitel: Krokoms kommun - Krokoms kommun
# Region Kronoberg har sidtitel: Region Kronoberg
# Lekebergs kommun har sidtitel: Startsida - Lekebergs kommun
# Lerums kommun har sidtitel: Lerums kommun
# ERROR! Lidingö kommun vill inte. Felmeddelande: HTTPSConnectionPool(host='www.lidingo.se', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
# Lidköpings kommun har sidtitel: Lidköpings kommun - Lidköpings kommun
# Lindesbergs kommun har sidtitel: Lindesberg.se - Lindesbergs kommun
# Linköpings kommun har sidtitel: V&#228;lkommen till Link&#246;ping - D&#228;r id&#233;er blir verklighet - linkoping.se
# ERROR! Ljungby kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Luleå kommun har sidtitel: Luleå kommun - Luleå kommun
# ERROR! Lunds kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Mariestads kommun har sidtitel: Mariestads kommun
# Mölndals kommun har sidtitel: Startsida - Mölndal
# Nacka kommun har sidtitel: Nacka kommun
# Norrköpings kommun har sidtitel: Norrkoping - Norrkoping
# Olofströms kommun har sidtitel: Olofström - Olofström
# Orusts kommun har sidtitel: Startsida - Orust kommun
# Oxelösunds kommun har sidtitel: Oxelösund - Oxelösund
# Piteå kommun har sidtitel: Pite&#229;
# Ragunda kommun har sidtitel: Ragunda kommun - Ragunda kommun
# Region Gotland har sidtitel: Startsida - Region Gotland
# Region Skåne har sidtitel: Start - Region Sk&#229;ne
# Sala kommun har sidtitel: Startsida för www.sala.se - Sala kommun
# Salems kommun har sidtitel: Kommunens officiella webbplats | Salems Kommun
# Sandvikens kommun har sidtitel: Startsida - Sandvikens kommun
# Simrishamns kommun har sidtitel: Simrishamns kommun
# Sjöbo kommun har sidtitel: Sjöbo kommun - Sjöbo kommun
# Skellefteå kommun har sidtitel: Startsida - Skellefteå kommun
# Skinnskattebergs kommun har sidtitel: Skinnskatteberg | Skinnskattebergs kommun - Skinnskatteberg
# ERROR! Skövde kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Sollentuna kommun har sidtitel: Sollentuna kommun
# Stockholms kommun har sidtitel: Stockholms stad
# Strängnäs kommun har sidtitel: Strängnäs kommun - Strängnäs kommun
# Strömsunds kommun har sidtitel: Strömsunds kommun - Strömsunds kommun
# Sundbybergs kommun har sidtitel: Sundbybergs stad - Sundbybergs stad
# Sundsvalls kommun har sidtitel: Sundsvalls kommun
# ERROR! Sunne kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Söderhamns kommun har sidtitel: Söderhamns kommun - Söderhamns kommun
# Söderköpings kommun har sidtitel: Startsida - S&#246;derk&#246;pings kommun
# Södertälje kommun har sidtitel: Startsida
# Sölvesborgs kommun har sidtitel: Sölvesborg - Sölvesborgs kommun
# Tanums kommun har sidtitel: Tanums kommun - Tanums kommun
# Tidaholms kommun har sidtitel: Tidaholms kommun - Tidaholms kommun
# Tierps kommun har sidtitel: Tierps kommun - tierp.se
# Timrå kommun har sidtitel: timra.se - Timrå kommun
# Tjörns kommun har sidtitel: Tjörns kommun - Tjörns kommun
# Tomelilla kommun har sidtitel: Tomelilla kommun: Startsida | Tomelilla
# Torsby kommun har sidtitel: Torsby.se - Torsby.se
# Tranås kommun har sidtitel: Tranås - Tranås
# Trollhättans kommun har sidtitel: Trollh&#228;ttans Stad - Trollh&#228;ttans stad
# Töreboda kommun har sidtitel: Töreboda kommun
# Uddevalla kommun har sidtitel: Uddevalla kommun - Uddevalla kommun
# Umeå kommun har sidtitel: Umeå kommun - Umeå kommun
# Upplands Väsby kommun har sidtitel: Upplands Väsby kommun - Upplands Väsby kommun
# Upplands-bro kommun har sidtitel: Upplands-Bro - Upplands-Bro
# Uppsala kommun har sidtitel: Uppsala kommun – Uppsala.se - Uppsala kommun
# Vara kommun har sidtitel: Vara kommun — Startsida
# ERROR! Varbergs kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# ERROR! Vetlanda kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Vimmerby kommun har sidtitel: Vimmerby kommun - Vimmerby kommun
# ERROR! Vindelns kommun vill inte. Felmeddelande: HTTPSConnectionPool(host='www.vindeln.se', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
# Vårgårda kommun har sidtitel: Vårgårda kommun - Vårgårda kommun
# Värmdö kommun har sidtitel: Värmdö kommun - Värmdö kommun
# ERROR! Västerviks kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Västerås kommun har sidtitel: Västerås - Västerås
# Västra Götalandsregionen har sidtitel: V&#228;stra G&#246;talandsregionen - V&#228;stra G&#246;talandsregionen
# ERROR! Ystads kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Ånge kommun har sidtitel: Ånge kommun - Ånge kommun
# Åsele kommun har sidtitel: &#197;sele kommun - Åsele kommun
# Älvkarleby kommun har sidtitel: Älvkarleby.se - Älvkarleby kommuns webbplats
# ERROR! Ängelholms kommun vill inte. Felmeddelande: ('Connection aborted.', TimeoutError(60, 'Operation timed out'))
# Örebro kommun har sidtitel: Välkommen till Örebro kommun - orebro.se
# Östersunds kommun har sidtitel: Östersund.se - Startsida
# Ale kommun har sidtitel: ale.se | ale.se
# Alingsås kommun har sidtitel: Välkommen till Alingsås kommun - Alingsås kommun
# Alvesta kommun har sidtitel: Alvesta - S&#246;dra Sveriges mittpunkt
# ERROR! Aneby kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Arboga kommun har sidtitel: Arboga kommun - Arboga kommun
# Arjeplogs kommun har sidtitel: Startsida - Arjeplogs kommun
# Arvika kommun har sidtitel: Arvika - Startsida
# Askersunds kommun har sidtitel: Askersunds kommun - Askersunds kommun
# Avesta kommun har sidtitel: Avesta kommuns webbplats
# Bengtsfors kommun har sidtitel: Bengtsfors kommun - Bengtsfors kommun
# Bjurholms kommun har sidtitel: Bjurholm kommun
# Bjuvs kommun har sidtitel: Bjuvs kommun - Bjuvs kommun
# Bodens kommun har sidtitel: boden.se
# Bollnäs kommun har sidtitel: Bollnas kommun
# Borgholms kommun har sidtitel: Borgholms kommun på Öland
# Borlänge kommun har sidtitel: Borlänge - Borlänge
# Borås kommun har sidtitel: Borås Stad - Borås Stad
# Boxholms kommun har sidtitel: Välkommen till Boxholm
# Bromölla kommun har sidtitel: Start - Brom&#246;lla Kommun
# Bräcke kommun har sidtitel: Bräcke kommun - Bräcke kommun
# Burlövs kommun har sidtitel: Burlöv - Burlöv
# Dals-eds kommun har sidtitel: Dals-Eds kommun - Dals-Eds kommun
# Danderyds kommun har sidtitel: Startsida – Danderyds kommun
# Eda kommun har sidtitel: Hem
# Ekerö kommun har sidtitel: Ekerö kommun - Ekerö kommun
# ERROR! Eksjö kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Emmaboda kommun har sidtitel: www.emmaboda.se - Startsida
# ERROR! Enköpings kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Eslövs kommun har sidtitel: Startsidan - Eslövs kommun
# Essunga kommun har sidtitel: Essunga kommun - Essunga kommun
# Fagersta kommun har sidtitel: Fagersta kommun
# Filipstads kommun har sidtitel: Filipstads kommun - Filipstads kommun
# Finspångs kommun har sidtitel: Finspångs kommun - Finspångs kommun
# Flens kommun har sidtitel: Flens kommun | Sörmlands hjärta
# Färgelanda kommun har sidtitel: F&#228;rgelanda kommun - F&#228;rgelanda kommun
# Gagnefs kommun har sidtitel: Startsida Gagnef kommun - Gagnefs Kommun
# Gislaveds kommun har sidtitel: Gislaved.se - Gislaved.se
# Gnosjö kommun har sidtitel: gnosjo.se - Gnosjö kommun
# Grästorps kommun har sidtitel: Startsida - Startsida
# ERROR! Gällivare kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Göteborgs kommun har sidtitel: Start  - Göteborgs Stad
# Habo kommun har sidtitel: Hem | Habo kommun
# Hagfors kommun har sidtitel: Hagfors kommun - Hagfors kommun
# Hallsbergs kommun har sidtitel: Hallsbergs kommun - Hallsbergs kommun
# Hallstahammars kommun har sidtitel: Hallstahammars kommun - Hallstahammars kommun
# Hammarö kommun har sidtitel: Startsida - Hammar&#246; kommun
# Haninge kommun har sidtitel: Just a moment...
# Hedemora kommun har sidtitel: Hedemora Kommun
# Herrljunga kommun har sidtitel: Herrljunga kommun - Herrljunga kommun
# Hjo kommun har sidtitel: Hjo kommun - Tr&#228;staden vid V&#228;ttern - Hjo kommun
# Hofors kommun har sidtitel: Hofors kommun
# Hudiksvalls kommun har sidtitel: Hudiksvalls kommun
# Härjedalens kommun har sidtitel: Härjedalens kommun - Härjedalens kommun
# Härryda kommun har sidtitel: Härryda kommun - Härryda kommun
# Hässleholms kommun har sidtitel: Hässleholms kommun - Hässleholms kommun
# Höganäs kommun har sidtitel: Höganäs kommun – Höganäs kommun
# Högsby kommun har sidtitel: Högsby kommun
# Hörby kommun har sidtitel: Hörby.se | Hörby kommuns officiella webbplats med service och information för invånare, företagare och besökare.
# Höörs kommun har sidtitel: Höörs kommun
# ERROR! Jokkmokks kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Region Jämtland Härjedalen har sidtitel: Region Jämtland Härjedalen - Startsida
# Järfälla kommun har sidtitel: Järfälla - Järfälla kommun
# Jönköpings kommun har sidtitel: Välkommen till Jönköpings kommun - www.jonkoping.se - Jönköpings kommun
# Kalmar kommun har sidtitel: Kalmar - Kalmar
# Karlsborgs kommun har sidtitel: Karlsborgs kommun - Guldplatsen vid V&#228;ttern - Karlsborgs Kommun
# Katrineholms kommun har sidtitel: Katrineholms kommun
# Kils kommun har sidtitel: V&#228;lkommen till Kils kommun
# Kiruna kommun har sidtitel: Kiruna kommun - Kiruna kommun
# Klippans kommun har sidtitel: Klippans kommun - Klippans kommun
# Knivsta kommun har sidtitel: Knivsta - Knivsta
# Kristianstads kommun har sidtitel: Startsida - Kristianstads kommun
# Kristinehamns kommun har sidtitel: Start
# Kumla kommun har sidtitel: Kumla kommun - Startsida
# Kungsbacka kommun har sidtitel: Kungsbacka kommun
# Kungsörs kommun har sidtitel: Kungsörs kommun - Kungsörs kommun
# Kungälvs kommun har sidtitel: Kung&#228;lvs kommun - kungalv.se
# Kävlinge kommun har sidtitel: Kävlinge kommun
# Köpings kommun har sidtitel: Köpings kommun - Köpings kommun
# ERROR! Laholms kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Landskrona kommun har sidtitel: Just a moment...
# Region Blekinge har sidtitel: Region Blekinge - Region Blekinge
# Region Dalarna har sidtitel: Start - Region Dalarna
# Region Gävleborg har sidtitel: Start - Region G&#228;vleborg
# Region Jönköpings Län har sidtitel: Region J&#246;nk&#246;pings l&#228;n, Region J&#246;nk&#246;pings l&#228;n
# Region Kalmar län har sidtitel: Startsida | Region Kalmar L&#228;n
# Region Uppsala har sidtitel: Region Uppsala - H&#228;r v&#228;xer kunskap och m&#228;nniskor
# Region Värmland har sidtitel: Region Värmland - Region Värmland
# ERROR! Region Östergötland vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Region Sörmland har sidtitel: Region S&#246;rmland - Region S&#246;rmland
# Region Västernorrland har sidtitel: Region V&#228;sternorrland
# Region Västmanland har sidtitel: Region V&#228;stmanland – Livskraft f&#246;r framtiden
# Laxå kommun har sidtitel: Laxå kommun - Laxå kommun
# Leksands kommun har sidtitel: Leksands kommun
# Lessebo kommun har sidtitel: Lessebo - Lessebo
# Lilla Edets kommun har sidtitel: Lilla Edets kommun - Lilla Edets kommun
# Ljusdals kommun har sidtitel: Ljusdals kommun
# Ljusnarsbergs kommun har sidtitel: Ljusnarsbergs kommun - Ljusnarsbergs kommun
# Lomma kommun har sidtitel: Lomma kommun
# Ludvika kommun har sidtitel: Startsida - Ludvika kommun
# Lycksele kommun har sidtitel: Lycksele Kommun
# Lysekils kommun har sidtitel: Lysekils kommun - Startsida
# Malmö kommun har sidtitel: Startsidan - Malmö stad
# Malung-Sälens kommun har sidtitel: Malung-Sälen
# Malå kommun har sidtitel: Startsida | Mal&#229; Kommun
# Markaryds kommun har sidtitel: Markaryd - Markaryd
# Marks kommun har sidtitel: Startsida - Marks kommun
# Melleruds kommun har sidtitel: Melleruds kommun
# Mjölby kommun har sidtitel: Mjolby.se - Mjölby kommun
# Mora kommun har sidtitel: Mora kommun - Mora kommun
# Motala kommun har sidtitel: 403 Forbidden
# Mullsjö kommun har sidtitel: Mullsjö - Mullsjö
# Munkedals kommun har sidtitel: Munkedals kommun - Munkedals kommun
# Munkfors kommun har sidtitel: Munkfors kommun - I hjärtat av Värmland, längs Klarälven
# Mönsterås kommun har sidtitel: Mönsterås kommun
# ERROR! Mörbylånga kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Nora kommun har sidtitel: Nora kommun - Nora kommun
# Norbergs kommun har sidtitel: Norbergs kommun - Norbergs kommun
# Nordanstigs kommun har sidtitel: Nordanstig | Nordanstig
# Nordmalings kommun har sidtitel: Nordmalings kommun
# ERROR! Region Norrbotten vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Norrtälje kommun har sidtitel: Norrtälje kommuns officiella webbplats
# Norsjö kommun har sidtitel: Norsjö kommun
# Nybro kommun har sidtitel: Nybro kommun
# Nykvarns kommun har sidtitel: Startsida - Nykvarns kommun
# Nyköpings kommun har sidtitel: nykoping.se - Start - Nykoping.se
# Nynäshamns kommun har sidtitel: Nynäshamns kommun
# ERROR! Nässjö kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# ERROR! Ockelbo kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Orsa kommun har sidtitel: Orsa kommun - Orsa kommun
# Osby kommun har sidtitel: På spåret och naturligt nära - Osby kommun
# Oskarshamns kommun har sidtitel: V&#228;lkommen till Oskarshamns kommun - Oskarshamns kommun
# Ovanåkers kommun har sidtitel: Ovanaker.se - Ovanåkers kommun
# Pajala kommun har sidtitel: Pajala - Pajala Kommun
# ERROR! Partille kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Perstorps kommun har sidtitel: Perstorps kommun - Perstorps kommun
# Region Halland har sidtitel: Förstasidan - Region Halland
# ERROR! Robertsfors kommun vill inte. Felmeddelande: HTTPSConnectionPool(host='www.robertsfors.se', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
# Ronneby kommun har sidtitel: ronneby.se - ronneby.se
# Rättviks kommun har sidtitel: Välkommen till Rättvik
# Sigtuna kommun har sidtitel: Sigtuna kommun - Sigtuna kommun
# Skara kommun har sidtitel: Skara kommun - Skara kommuns startsida
# Skurups kommun har sidtitel: Skurups kommun
# Smedjebackens kommun har sidtitel: Smedjebackens kommun
# Sollefteå kommun har sidtitel: Sollefteå kommun - Sollefteå kommun
# ERROR! Solna kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Sorsele kommun har sidtitel: V&#228;lkommen till Sorsele
# Sotenäs kommun har sidtitel: Sotenäs kommun - Sotenäs kommun
# ERROR! Staffanstorps kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Stenungsunds kommun har sidtitel: Startsida - Stenungsunds kommun
# Region Stockholm har sidtitel:    - Region Stockholm
# Storfors kommun har sidtitel: Storfors Kommun - Storfors Kommun
# ERROR! Storumans kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Strömstads kommun har sidtitel: Strömstad - Strömstad
# Surahammars kommun har sidtitel: Surahammars kommun - Surahammars kommun
# Svalövs kommun har sidtitel: Svalövs kommun
# Svedala kommun har sidtitel: Svedala kommuns officiella webbplats - Svedala kommun
# Svenljunga kommun har sidtitel: Svenljunga.se - Svenljunga.se
# Säffle kommun har sidtitel: Säffle kommun - Säffle kommun
# Säters kommun har sidtitel: Startsidan | Säter kommun
# ERROR! Sävsjö kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Tibro kommun har sidtitel: Startsida - Tibro Kommun
# Tingsryds kommun har sidtitel: Startsidan - Tingsryds kommun
# Torsås kommun har sidtitel: Torsås kommun
# Tranemo kommun har sidtitel: Tranemo Kommun — Startsida
# ERROR! Trelleborgs kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# ERROR! Trosa kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Tyresö kommun har sidtitel: Tyresö kommun - Tyresö kommun
# Täby kommun har sidtitel: T&#228;by kommun - T&#228;by kommun
# Ulricehamns kommun har sidtitel: Ulricehamns kommun — Startsida
# Uppvidinge kommun har sidtitel: Uppvidinge kommun - Uppvidinge kommun
# Vadstena kommun har sidtitel: Vadstena kommun
# Vaggeryds kommun har sidtitel: Vaggeryds kommun - Välkommen till Vaggeryds kommuns officiella webbplats ! Här hittar du information och nyheter om och från kommunen.
# Valdemarsviks kommun har sidtitel:
# Vallentuna kommun har sidtitel: Vallentuna kommun
# Vansbro kommun har sidtitel: Vansbro kommun - Vansbro kommun
# Vaxholms kommun har sidtitel: Vaxholms stad - Vaxholms stad
# Vellinge kommun har sidtitel: Vellinge kommun — Inv&#229;nare
# Vilhelmina kommun har sidtitel: Hem
# Vingåkers kommun har sidtitel: Vingåkers kommun - Startsida
# Vänersborgs kommun har sidtitel: Vänersborgs kommun - Vänersborgs kommun
# Vännäs kommun har sidtitel: Vännäs kommun
# Värnamo kommun har sidtitel: Varnamo.se - Värnamo kommun
# ERROR! Region Västerbotten vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Växjö kommun har sidtitel: Vaxjo.se - Växjö kommun
# Ydre kommun har sidtitel: Startsida - Ydre
# Åmåls kommun har sidtitel: &#197;m&#229;ls kommun - &#197;m&#229;ls kommun
# Åre kommun har sidtitel: Hem - Åre kommun
# Årjängs kommun har sidtitel: Årjäng - Årjäng
# Åstorps kommun har sidtitel: Åstorp - Åstorp
# Åtvidabergs kommun har sidtitel: Startsida - Åtvidabergs kommun
# Älmhults kommun har sidtitel: Älmhults kommun
# Älvdalens kommun har sidtitel: Älvdalens kommun - Älvdalens kommun
# Älvsbyns kommun har sidtitel:  Älvsbyns kommun
# ERROR! Öckerö kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'
# Ödeshögs kommun har sidtitel: Startsida - Ödeshögs kommun
# Region Örebro län har sidtitel: V&#228;lkommen till Region &#214;rebro l&#228;n!
# Örkelljunga kommun har sidtitel: Örkelljunga - Startsida
# Örnsköldsviks kommun har sidtitel: Välkommen till Örnsköldsviks kommun
# Österåkers kommun har sidtitel: Österåkers kommun - Österåkers kommun
# Östhammars kommun har sidtitel: V&#228;lkommen till - &#214;sthammars kommun
# Östra Göinge kommun har sidtitel:  Östra Göinge kommun
# Överkalix kommun har sidtitel: &#214;verkalix kommun - Överkalix.se
# ERROR! Övertorneå kommun vill inte. Felmeddelande: 'NoneType' object has no attribute 'lastindex'

# %% [markdown]
# ## 1.3 Vilka har lång sidtitel (för lång?)
# > "...for a page title to be useful for SEO it should still stick to around 60-70 characters."
# > – [How to Write the Perfect Page Title With SEO in Mind](https://blog.hubspot.com/blog/tabid/6307/bid/5984/spilling-seo-juice-3-dos-and-don-ts-for-writing-great-page-titles.aspx)
#
# Nedan kollar vi vilka webbplatser som har en sidtitel som är längre än 70 tecken.

# %%
sidtitel_langre_an = 70

for webbplats in webbplatser:
    if len(webbplatser[webbplats]) > 4 and webbplatser[webbplats][4] > sidtitel_langre_an:
        print(f'{webbplats} har:\n{webbplatser[webbplats][5]}')
# Out:
# Linköpings kommun har:
# V&#228;lkommen till Link&#246;ping - D&#228;r id&#233;er blir verklighet - linkoping.se
# Västra Götalandsregionen har:
# V&#228;stra G&#246;talandsregionen - V&#228;stra G&#246;talandsregionen
# Hörby kommun har:
# Hörby.se | Hörby kommuns officiella webbplats med service och information för invånare, företagare och besökare.
# Jönköpings kommun har:
# Välkommen till Jönköpings kommun - www.jonkoping.se - Jönköpings kommun
# Region Jönköpings Län har:
# Region J&#246;nk&#246;pings l&#228;n, Region J&#246;nk&#246;pings l&#228;n
# Vaggeryds kommun har:
# Vaggeryds kommun - Välkommen till Vaggeryds kommuns officiella webbplats ! Här hittar du information och nyheter om och från kommunen.

# %% [markdown]
# ## 1.4 Vilka har märkligt korta sidtitlar?

# %%
sidtitel_kortare_an = 12

for webbplats in webbplatser:
    if len(webbplatser[webbplats]) > 4 and webbplatser[webbplats][4] < sidtitel_kortare_an:
        # lista alla med kortare än 8, där kan finnas "Hem" etc
        print(f'{webbplats} har endast: {webbplatser[webbplats][5]}')
# Out:
# Heby kommun har endast: Heby kommun
# Håbo kommun har endast: Håbo - Håbo
# Piteå kommun har endast: Pite&#229;
# Södertälje kommun har endast: Startsida
# Bodens kommun har endast: boden.se
# Eda kommun har endast: Hem
# Kristinehamns kommun har endast: Start
# Valdemarsviks kommun har endast:
# Vilhelmina kommun har endast: Hem

# %% [markdown]
# # 2. Kolla om Wikidata har befolkningsmängd
# Förutsätter:
# * [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# * [requests](https://requests.readthedocs.io/en/latest/)

# %%
from bs4 import BeautifulSoup
import requests

for webbplats in webbplatser:
    try:
        wikidata_url = webbplatser[webbplats][3] # hämtar ut Wikidata-adressen för regionen / kommunen
        r = requests.get(wikidata_url)

        soup = BeautifulSoup(r.text) # matar in HTML-koden från Wikidata-sidan till BS4
        results = soup.find("div", {"data-property-id" : "P1082"}) # väljer ut DIV med population

        children = results.findChildren("div" , recursive=False) # välj alla underelement av typen DIV

        population = children[1].find_all("div", {"class" : "wikibase-snakview-body"})[-3].get_text().replace("\n", "").replace(",", "")
        print(f'{webbplats} har {population} st invånare')
        webbplatser[webbplats].append(population) # lägger till befolkning i organisationens array
    except Exception as e:
        print(f'{webbplats} vill inte! Felmeddelande: {e}')
# Out:
# Arvidsjaurs kommun har 6153 st invånare
# Bergs kommun har 7154 st invånare
# Bollebygds kommun har 9630 st invånare
# Botkyrka kommun har 95184 st invånare
# Båstads kommun har 15715 st invånare
# Degerfors kommun har 9526 st invånare
# Dorotea kommun har 2456 st invånare
# Eskilstuna kommun har 107708 st invånare
# Falkenbergs kommun har 46769 st invånare
# Falköpings kommun har 33313 st invånare
# Falu kommun har 59850 st invånare
# Forshaga kommun har 11632 st invånare
# Gnesta kommun har 11524 st invånare
# Grums kommun har 9078 st invånare
# Gullspångs kommun har 5157 st invånare
# Gävle kommun har 103246 st invånare
# Götene kommun har 13276 st invånare
# Halmstads kommun har 104693 st invånare
# Haparanda kommun har 9447 st invånare
# Heby kommun har 14339 st invånare
# Helsingborgs kommun har 150210 st invånare
# Huddinge kommun har 114187 st invånare
# Hultsfreds kommun har 14091 st invånare
# Hylte kommun har 10628 st invånare
# Håbo kommun har 22474 st invånare
# Hällefors kommun har 6824 st invånare
# Härnösands kommun har 24958 st invånare
# Kalix kommun har 15745 st invånare
# Karlshamns kommun har 32202 st invånare
# Karlskoga kommun har 30521 st invånare
# Karlskrona kommun har 66625 st invånare
# Karlstads kommun har 95562 st invånare
# Kinda kommun har 10053 st invånare
# Kramfors kommun har 17977 st invånare
# Krokoms kommun har 15403 st invånare
# Region Kronoberg vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Lekebergs kommun har 8649 st invånare
# Lerums kommun har 43463 st invånare
# Lidingö kommun har 48261 st invånare
# Lidköpings kommun har 40487 st invånare
# Lindesbergs kommun har 23594 st invånare
# Linköpings kommun har 165557 st invånare
# Ljungby kommun har 28421 st invånare
# Luleå kommun har 78826 st invånare
# Lunds kommun har 127725 st invånare
# Mariestads kommun har 24781 st invånare
# Mölndals kommun har 70098 st invånare
# Nacka kommun har 108299 st invånare
# Norrköpings kommun har 144610 st invånare
# Olofströms kommun har 13296 st invånare
# Orusts kommun har 15353 st invånare
# Oxelösunds kommun har 12159 st invånare
# Piteå kommun har 42334 st invånare
# Ragunda kommun har 5193 st invånare
# Region Gotland har 61009 st invånare
# Region Skåne vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Sala kommun har 22945 st invånare
# Salems kommun har 17293 st invånare
# Sandvikens kommun har 39190 st invånare
# Simrishamns kommun har 19222 st invånare
# Sjöbo kommun har 19553 st invånare
# Skellefteå kommun har 73615 st invånare
# Skinnskattebergs kommun har 4410 st invånare
# Skövde kommun har 57064 st invånare
# Sollentuna kommun har 75329 st invånare
# Stockholms kommun har 980260 st invånare
# Strängnäs kommun har 38297 st invånare
# Strömsunds kommun har 11479 st invånare
# Sundbybergs kommun har 53802 st invånare
# Sundsvalls kommun har 99341 st invånare
# Sunne kommun har 13345 st invånare
# Söderhamns kommun har 25438 st invånare
# Söderköpings kommun har 14760 st invånare
# Södertälje kommun har 101616 st invånare
# Sölvesborgs kommun har 17520 st invånare
# Tanums kommun har 12955 st invånare
# Tidaholms kommun har 12789 st invånare
# Tierps kommun har 21454 st invånare
# Timrå kommun har 17866 st invånare
# Tjörns kommun har 16325 st invånare
# Tomelilla kommun har 13714 st invånare
# Torsby kommun har 11475 st invånare
# Tranås kommun har 18880 st invånare
# Trollhättans kommun har 59155 st invånare
# Töreboda kommun har 9205 st invånare
# Uddevalla kommun har 57246 st invånare
# Umeå kommun har 131322 st invånare
# Upplands Väsby kommun har 48353 st invånare
# Upplands-bro kommun har 31282 st invånare
# Uppsala kommun har 238569 st invånare
# Vara kommun har 16164 st invånare
# Varbergs kommun har 66853 st invånare
# Vetlanda kommun har 27663 st invånare
# Vimmerby kommun har 15601 st invånare
# Vindelns kommun har 5524 st invånare
# Vårgårda kommun har 12212 st invånare
# Värmdö kommun har 46371 st invånare
# Västerviks kommun har 36736 st invånare
# Västerås kommun har 157300 st invånare
# Västra Götalandsregionen vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Ystads kommun har 31560 st invånare
# Ånge kommun har 9228 st invånare
# Åsele kommun har 2808 st invånare
# Älvkarleby kommun har 9620 st invånare
# Ängelholms kommun har 43693 st invånare
# Örebro kommun har 156994 st invånare
# Östersunds kommun har 64368 st invånare
# Ale kommun har 32238 st invånare
# Alingsås kommun har 41824 st invånare
# Alvesta kommun har 20273 st invånare
# Aneby kommun har 6878 st invånare
# Arboga kommun har 14097 st invånare
# Arjeplogs kommun har 2702 st invånare
# Arvika kommun har 25788 st invånare
# Askersunds kommun har 11507 st invånare
# Avesta kommun har 22847 st invånare
# Bengtsfors kommun har 9355 st invånare
# Bjurholms kommun har 2378 st invånare
# Bjuvs kommun har 15883 st invånare
# Bodens kommun har 28128 st invånare
# Bollnäs kommun har 26666 st invånare
# Borgholms kommun har 10833 st invånare
# Borlänge kommun har 52323 st invånare
# Borås kommun har 114230 st invånare
# Boxholms kommun har 5509 st invånare
# Bromölla kommun har 12614 st invånare
# Bräcke kommun har 6184 st invånare
# Burlövs kommun har 19793 st invånare
# Dals-eds kommun har 4743 st invånare
# Danderyds kommun har 32825 st invånare
# Eda kommun har 8521 st invånare
# Ekerö kommun har 29188 st invånare
# Eksjö kommun har 17870 st invånare
# Emmaboda kommun har 9315 st invånare
# Enköpings kommun har 47621 st invånare
# Eslövs kommun har 34601 st invånare
# Essunga kommun har 5691 st invånare
# Fagersta kommun har 13326 st invånare
# Filipstads kommun har 10372 st invånare
# Finspångs kommun har 21872 st invånare
# Flens kommun har 16281 st invånare
# Färgelanda kommun har 6569 st invånare
# Gagnefs kommun har 10498 st invånare
# Gislaveds kommun har 29562 st invånare
# Gnosjö kommun har 9566 st invånare
# Grästorps kommun har 5724 st invånare
# Gällivare kommun har 17468 st invånare
# Göteborgs kommun har 589383 st invånare
# Habo kommun har 12876 st invånare
# Hagfors kommun har 11549 st invånare
# Hallsbergs kommun har 16245 st invånare
# Hallstahammars kommun har 16642 st invånare
# Hammarö kommun har 16801 st invånare
# Haninge kommun har 96141 st invånare
# Hedemora kommun har 15400 st invånare
# Herrljunga kommun har 9489 st invånare
# Hjo kommun har 9259 st invånare
# Hofors kommun har 9552 st invånare
# Hudiksvalls kommun har 37692 st invånare
# Härjedalens kommun har 10114 st invånare
# Härryda kommun har 39313 st invånare
# Hässleholms kommun har 52367 st invånare
# Höganäs kommun har 27812 st invånare
# Högsby kommun har 5611 st invånare
# Hörby kommun har 15802 st invånare
# Höörs kommun har 17029 st invånare
# Jokkmokks kommun har 4766 st invånare
# Region Jämtland Härjedalen vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Järfälla kommun har 83489 st invånare
# Jönköpings kommun har 143901 st invånare
# Kalmar kommun har 71396 st invånare
# Karlsborgs kommun har 7007 st invånare
# Katrineholms kommun har 34672 st invånare
# Kils kommun har 12132 st invånare
# Kiruna kommun har 22623 st invånare
# Klippans kommun har 17774 st invånare
# Knivsta kommun har 19827 st invånare
# Kristianstads kommun har 86600 st invånare
# Kristinehamns kommun har 24071 st invånare
# Kumla kommun har 22233 st invånare
# Kungsbacka kommun har 85468 st invånare
# Kungsörs kommun har 8764 st invånare
# Kungälvs kommun har 48547 st invånare
# Kävlinge kommun har 32353 st invånare
# Köpings kommun har 26120 st invånare
# Laholms kommun har 26429 st invånare
# Landskrona kommun har 46552 st invånare
# Region Blekinge vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Dalarna vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Gävleborg vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Jönköpings Län vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Kalmar län vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Uppsala vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Värmland vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Östergötland vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Sörmland vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Västernorrland vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Region Västmanland vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Laxå kommun har 5589 st invånare
# Leksands kommun har 16018 st invånare
# Lessebo kommun har 8565 st invånare
# Lilla Edets kommun har 14452 st invånare
# Ljusdals kommun har 18788 st invånare
# Ljusnarsbergs kommun har 4571 st invånare
# Lomma kommun har 24632 st invånare
# Ludvika kommun har 26504 st invånare
# Lycksele kommun har 12282 st invånare
# Lysekils kommun har 14237 st invånare
# Malmö kommun har 353145 st invånare
# Malung-Sälens kommun har 10229 st invånare
# Malå kommun vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Markaryds kommun har 10295 st invånare
# Marks kommun har 35236 st invånare
# Melleruds kommun har 9256 st invånare
# Mjölby kommun har 28335 st invånare
# Mora kommun har 20657 st invånare
# Motala kommun har 43738 st invånare
# Mullsjö kommun har 7457 st invånare
# Munkedals kommun har 10561 st invånare
# Munkfors kommun har 3690 st invånare
# Mönsterås kommun har 13269 st invånare
# Mörbylånga kommun har 15800 st invånare
# Nora kommun har 10731 st invånare
# Norbergs kommun har 5678 st invånare
# Nordanstigs kommun har 9491 st invånare
# Nordmalings kommun har 7075 st invånare
# Region Norrbotten vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Norrtälje kommun har 64934 st invånare
# Norsjö kommun har 3968 st invånare
# Nybro kommun har 20277 st invånare
# Nykvarns kommun har 11509 st invånare
# Nyköpings kommun har 57773 st invånare
# Nynäshamns kommun har 29629 st invånare
# Nässjö kommun har 31796 st invånare
# Ockelbo kommun har 5877 st invånare
# Orsa kommun har 6953 st invånare
# Osby kommun har 13276 st invånare
# Oskarshamns kommun har 27188 st invånare
# Ovanåkers kommun har 11694 st invånare
# Pajala kommun har 5943 st invånare
# Partille kommun har 39623 st invånare
# Perstorps kommun har 7516 st invånare
# Region Halland vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Robertsfors kommun har 6747 st invånare
# Ronneby kommun har 29172 st invånare
# Rättviks kommun har 11118 st invånare
# Sigtuna kommun har 50548 st invånare
# Skara kommun har 18742 st invånare
# Skurups kommun har 16453 st invånare
# Smedjebackens kommun har 10950 st invånare
# Sollefteå kommun har 18759 st invånare
# Solna kommun har 84620 st invånare
# Sorsele kommun har 2455 st invånare
# Sotenäs kommun har 9141 st invånare
# Staffanstorps kommun har 26324 st invånare
# Stenungsunds kommun har 27636 st invånare
# Region Stockholm vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Storfors kommun har 3935 st invånare
# Storumans kommun har 5781 st invånare
# Strömstads kommun har 13269 st invånare
# Surahammars kommun har 10120 st invånare
# Svalövs kommun har 14478 st invånare
# Svedala kommun har 23296 st invånare
# Svenljunga kommun har 10811 st invånare
# Säffle kommun har 15318 st invånare
# Säters kommun har 11300 st invånare
# Sävsjö kommun har 11745 st invånare
# Tibro kommun har 11298 st invånare
# Tingsryds kommun har 12345 st invånare
# Torsås kommun har 7104 st invånare
# Tranemo kommun har 11932 st invånare
# Trelleborgs kommun har 46386 st invånare
# Trosa kommun vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Tyresö kommun har 49162 st invånare
# Täby kommun har 74253 st invånare
# Ulricehamns kommun har 25002 st invånare
# Uppvidinge kommun har 9420 st invånare
# Vadstena kommun vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Vaggeryds kommun har 14811 st invånare
# Valdemarsviks kommun har 7603 st invånare
# Vallentuna kommun har 34370 st invånare
# Vansbro kommun har 6776 st invånare
# Vaxholms kommun har 11971 st invånare
# Vellinge kommun har 37591 st invånare
# Vilhelmina kommun har 6471 st invånare
# Vingåkers kommun har 9064 st invånare
# Vänersborgs kommun har 39651 st invånare
# Vännäs kommun har 9072 st invånare
# Värnamo kommun har 34700 st invånare
# Region Västerbotten vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Växjö kommun har 96117 st invånare
# Ydre kommun har 3679 st invånare
# Åmåls kommun har 12271 st invånare
# Åre kommun har 12284 st invånare
# Årjängs kommun har 9899 st invånare
# Åstorps kommun har 16332 st invånare
# Åtvidabergs kommun har 11492 st invånare
# Älmhults kommun har 18023 st invånare
# Älvdalens kommun har 7041 st invånare
# Älvsbyns kommun har 7974 st invånare
# Öckerö kommun har 12864 st invånare
# Ödeshögs kommun har 5314 st invånare
# Region Örebro län vill inte! Felmeddelande: 'NoneType' object has no attribute 'findChildren'
# Örkelljunga kommun har 10489 st invånare
# Örnsköldsviks kommun har 55763 st invånare
# Österåkers kommun har 48449 st invånare
# Östhammars kommun har 22358 st invånare
# Östra Göinge kommun har 14887 st invånare
# Överkalix kommun har 3215 st invånare
# Övertorneå kommun har 4192 st invånare

# %% [markdown]
# ## 2.1 Bara visa kommuner större än xx

# %%
kommuner_storre_an = 100000

for webbplats in webbplatser:
    if webbplatser[webbplats][-1].isnumeric() and int(webbplatser[webbplats][-1]) > kommuner_storre_an:
        print(f'{webbplats} har {webbplatser[webbplats][-1]} invånare')
# Out:
# Eskilstuna kommun har 107708 invånare
# Gävle kommun har 103246 invånare
# Halmstads kommun har 104693 invånare
# Helsingborgs kommun har 150210 invånare
# Huddinge kommun har 114187 invånare
# Linköpings kommun har 165557 invånare
# Lunds kommun har 127725 invånare
# Nacka kommun har 108299 invånare
# Norrköpings kommun har 144610 invånare
# Stockholms kommun har 980260 invånare
# Södertälje kommun har 101616 invånare
# Umeå kommun har 131322 invånare
# Uppsala kommun har 238569 invånare
# Västerås kommun har 157300 invånare
# Örebro kommun har 156994 invånare
# Borås kommun har 114230 invånare
# Göteborgs kommun har 589383 invånare
# Jönköpings kommun har 143901 invånare
# Malmö kommun har 353145 invånare
